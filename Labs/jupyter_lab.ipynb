# %% [markdown]
# # Marco's favourite travel destination

# %% [markdown]
# ### 1.l Why are we creating this notebook?
#
# The purpose of this notewbook is to learn the basic commands of jupyter by introducing Marco and his favourite travel destination!

# %%
name = input("Travellers name")
# Out:
# Travellers nameMarco

# %%
from IPython.display import Image
Image("https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Pierre-Person.jpg/800px-Pierre-Person.jpg")

# %% [markdown]
# ### Where does he love to go?
# His favoutite destination is Firenze, in Italy.

# %%
from IPython.display import Image
Image("https://www.italia.it/content/dam/tdh/en/interests/toscana/firenze/firenze/media/20210401173629-firenze-toscana-gettyimages-1145040590.jpg.transform/w_1600/h_900/image.jpeg")

# %% [markdown]
# ### His favourite things in Firenze are:
#  - Food
#  - Museums
#  - Nightlife

# %% [markdown]
# ### Other Resources:
#
# If you want to learn more about Firenze, click on thid [link](https://www.youtube.com/watch?v=x20K_ZOx5b0)
